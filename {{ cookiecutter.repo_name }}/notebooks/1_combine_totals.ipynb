# %% [markdown]
# # Connect to database
#
# ## Load the packages

# %%
# Clear all variables
# %reset -f

import os
import pandas as pd

from config import settings
from src import project_dir
project_dir

# JCG git functions
with open(os.path.join(project_dir,'src','mypackages_import_all.py'), 'r') as f:
    exec(f.read())

# %% [markdown]
# ## Load the data

# %%
file_path = os.path.join(settings.filepath_data,'farmsize','data','processed','FarmSize_aggregate_global_various_20240620.csv')
df_fsize = pd.read_csv(file_path)

file_path = os.path.join(settings.filepath_data,'ISOcodes','ISOcode_global_various_20240620_JCG.xlsx')
df_iso = pd.read_excel(file_path,sheet_name='final')
df_iso
# Out:
#     iso_code                           country Region_unsd1     Region_unsd2  \
# 0        AFG                       Afghanistan         Asia    Southern Asia
# 1        ALB                           Albania       Europe  Southern Europe
# 2        DZA                           Algeria       Africa  Northern Africa
# 3        ASM                    American Samoa      Oceania        Polynesia
# 4        AND                           Andorra       Europe  Southern Europe
# ..       ...                               ...          ...              ...
# 234      MDA               Republic of Moldova       Europe   Eastern Europe
# 235      KNA             Saint Kitts and Nevis     Americas        Caribbean
# 236      VCT  Saint Vincent and the Grenadines     Americas        Caribbean
# 237      YUG                      Yugoslav SFR       Europe  Southern Europe
# 238      REU                          Réunion       Africa   Eastern Africa
#
# ...
